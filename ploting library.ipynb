# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',periods=10),columns = list('ABCD'))

# %%
df=pd.DataFrame(np.random.randn(10,4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.379917  1.641343 -0.584984 -0.665676
# 1  0.938443 -1.195350 -0.970993 -1.317115
# 2 -2.043009  0.416983  0.208486  0.743952
# 3  0.983236 -1.112720 -0.462709  1.208788
# 4 -0.091636  0.999850  0.879183 -0.183482
# 5  0.035815 -0.446244  1.095224  1.023167
# 6 -1.220403 -0.478762 -1.011432  0.548202
# 7  0.934539  1.242129  0.025154 -1.025235
# 8 -1.705316  2.099638  0.352115  0.187710
# 9  0.170866  0.374122 -0.463519  1.110166

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -1.339914 -0.525938  0.005782  1.890350
# 2000-01-02 -0.758412  1.002410 -0.099247  0.912891
# 2000-01-03  1.151412 -0.221443 -1.003471 -0.089595
# 2000-01-04 -0.793664  0.799442  1.315924 -0.962499
# 2000-01-05 -1.804044 -0.553000 -0.109878 -0.615752
# 2000-01-06  1.267574  0.124021  0.693288 -0.274234
# 2000-01-07 -0.428622 -0.518961 -0.868277  1.299332
# 2000-01-08 -0.096768  1.441005  0.789456  0.150359
# 2000-01-09 -0.996323 -0.746717 -0.253835  1.740290
# 2000-01-10  0.247384  1.926526 -0.548982 -0.324376

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['A'].plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from numpy.random import randn,randint,uniform,sample

# %%
np.random.randn(1000)
# Out:
# array([-4.36422343e-01, -8.59267953e-01, -9.10463954e-01, -7.67430993e-02,
#        -8.85449142e-01,  8.49258183e-01,  1.65183800e+00,  1.12907722e+00,
#        -2.16645696e+00,  1.46870741e+00,  1.28162254e-01,  3.56337607e-01,
#         1.07976551e+00,  1.38700235e+00,  9.07109321e-02, -9.85141294e-01,
#         1.80804570e+00,  2.93841634e+00, -1.37893329e+00, -9.68199177e-01,
#         9.37128850e-01, -1.03160387e-01,  8.61031166e-01, -5.19509405e-02,
#         4.48723095e-01,  6.10457616e-01, -1.71557017e-01, -3.34205272e-01,
#        -2.25121056e-01,  5.68548185e-01,  1.06031755e+00,  1.58127337e+00,
#         7.56838371e-01,  7.34915941e-01,  1.46404971e+00, -6.74868591e-01,
#         1.10346243e-01,  2.21654976e-01,  8.63731703e-01,  8.76380333e-01,
#         1.67605685e+00,  2.18328467e-01, -1.07179379e+00, -6.49261919e-01,
#        -1.21325088e+00, -7.75318438e-01, -1.85042130e+00,  3.21157285e-01,
# ...

# %%
pd.DataFrame(randn(1000))
# Out:
#             0
# 0   -2.003129
# 1   -0.266700
# 2   -0.226154
# 3    0.450140
# 4   -1.060290
# ..        ...
# 995  0.433276
# 996  1.351661
# 997 -0.250164
# 998  1.011351
# 999  0.712767
#
# [1000 rows x 1 columns]

# %%
df=pd.DataFrame(randn(1000),index=pd.date_range('1/1/2000',periods=1000),columns = ['tushar'])

# %%
df
# Out:
#               tushar
# 2000-01-01 -0.200396
# 2000-01-02  0.137136
# 2000-01-03 -0.274456
# 2000-01-04 -0.350337
# 2000-01-05  1.340923
# ...              ...
# 2002-09-22 -1.343304
# 2002-09-23 -1.306068
# 2002-09-24  1.123718
# 2002-09-25 -0.561392
# 2002-09-26  0.486709
#
# [1000 rows x 1 columns]

# %%
ts=pd.Series(randn(1000),index=pd.date_range('1/1/2000',periods=1000))

# %%
ts
# Out:
# 2000-01-01   -1.360774
# 2000-01-02    1.142582
# 2000-01-03    0.732473
# 2000-01-04    0.785370
# 2000-01-05   -1.749661
#                 ...
# 2002-09-22   -0.519455
# 2002-09-23   -0.019933
# 2002-09-24    0.135335
# 2002-09-25    0.315359
# 2002-09-26    0.305824
# Freq: D, Length: 1000, dtype: float64

# %%
ts.plot()
# Out:
# <AxesSubplot:>

# %%
ts.plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
ax=iris.plot(figsize=(15,8),title='Iris dataset')
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
# Out:
# Text(0, 0.5, 'Y axis')

# %%
df=iris.drop(['species'],axis=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
iris['sepal_length'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x=pd.read_csv('titanic.csv')

# %%
x['Survived'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
x.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df.diff().hist(color='g',alpha=.3,figsize=(12,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.plot.scatter(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
d=df.iloc[0]

# %%
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,6))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d=df.head(5)

# %%
d
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
d.plot.pie(subplots=True,figsize=(20,20),fontsize=20,autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='sepal_length'>,
#        <AxesSubplot:ylabel='sepal_width'>,
#        <AxesSubplot:ylabel='petal_length'>,
#        <AxesSubplot:ylabel='petal_width'>], dtype=object)

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(8,8),diagonal='kde',color='g')
plt.show()
